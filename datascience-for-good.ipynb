# %%
import pandas as pd
pd.set_option("display.max_columns", 120)

# %%
df = pd.read_csv('./2016 School Explorer.csv')

# %%
df.tail()
# Out:
#      Adjusted Grade New? Other Location Code in LCGMS  \
# 1267            NaN  NaN                          NaN
# 1268            NaN  NaN                          NaN
# 1269            NaN  NaN                          NaN
# 1270            NaN  NaN                          NaN
# 1271            NaN  NaN                          NaN
#
#                                    School Name      SED Code Location Code  \
# 1267        FAMILY LIFE ACADEMY CHARTER SCHOOL  320900860839        84X705
# 1268             HARRIET TUBMAN CHARTER SCHOOL  320900860823        84X706
# 1269                      ICAHN CHARTER SCHOOL  320900860835        84X717
# 1270  BRONX CHARTER SCHOOL FOR BETTER LEARNING  321100860855        84X718
# 1271         BRONX CHARTER SCHOOL FOR THE ARTS  320800860846        84X730
#
#       District   Latitude  Longitude  \
# 1267         9  40.840277 -73.918654
# 1268         9  40.832272 -73.905817
# 1269         9  40.839176 -73.904982
# ...

# %%
for k, sdf in df.groupby(by=['City']):
    print(k)
# Out:
# ARVERNE
# ASTORIA
# BAYSIDE
# BELLEROSE
# BROAD CHANNEL
# BRONX
# BROOKLYN
# CAMBRIA HEIGHTS
# COLLEGE POINT
# CORONA
# DOUGLASTON
# EAST ELMHURST
# ELMHURST
# FAR ROCKAWAY
# FLORAL PARK
# FLUSHING
# FOREST HILLS
# GLENDALE
# HOLLIS
# HOWARD BEACH
# JACKSON HEIGHTS
# JAMAICA
# KEW GARDENS
# LITTLE NECK
# LONG ISLAND CITY
# MASPETH
# MIDDLE VILLAGE
# NEW YORK
# OZONE PARK
# QUEENS VILLAGE
# REGO PARK
# RICHMOND HILL
# RIDGEWOOD
# ROCKAWAY BEACH
# ROCKAWAY PARK
# ROOSEVELT ISLAND
# ROSEDALE
# SAINT ALBANS
# SOUTH OZONE PARK
# SOUTH RICHMOND HILL
# SPRINGFIELD GARDENS
# STATEN ISLAND
# WHITESTONE
# WOODHAVEN
# WOODSIDE

# %%
def replacer(c):
    for r in [' ', '?', '(', ')','/','%', '-']:
        c = c.replace(r, '')
    return c
df.columns = [replacer(c) for c in df.columns]
df.to_gbq('test.test2', 'dena-ai-training-16-gcp')
# Out:
# 1it [00:00,  5.89it/s]

# %%
import numpy as np
def ranker(df):
    df = df.sort_values('PercentWhite', ascending=False)
    df['rank'] = np.arange(len(df)) + 1
    return df
df.groupby(by=['City']).apply(ranker)[['City', 'PercentWhite','rank']].head(200)
# Out:
#                              City PercentWhite  rank
# City
# ARVERNE       920         ARVERNE           3%     1
#               874         ARVERNE           2%     2
# ASTORIA       1005        ASTORIA          43%     1
#               1010        ASTORIA          39%     2
#               1026        ASTORIA          31%     3
#               1031        ASTORIA          31%     4
#               1225        ASTORIA          30%     5
#               1027        ASTORIA          15%     6
# BAYSIDE       828         BAYSIDE          40%     1
#               846         BAYSIDE          34%     2
#               869         BAYSIDE          34%     3
#               851         BAYSIDE          31%     4
#               860         BAYSIDE          27%     5
#               823         BAYSIDE          23%     6
#               859         BAYSIDE          20%     7
#               852         BAYSIDE          18%     8
#               854         BAYSIDE          18%     9
# ...

# %%
df = pd.read_csv('./D5 SHSAT Registrations and Testers.csv')

# %%
df.head()
# Out:
#       DBN               School name  Year of SHST  Grade level  \
# 0  05M046    P.S. 046 Arthur Tappan          2013            8
# 1  05M046    P.S. 046 Arthur Tappan          2014            8
# 2  05M046    P.S. 046 Arthur Tappan          2015            8
# 3  05M046    P.S. 046 Arthur Tappan          2016            8
# 4  05M123  P.S. 123 Mahalia Jackson          2013            8
#
#    Enrollment on 10/31  Number of students who registered for the SHSAT  \
# 0                   91                                               31
# 1                   95                                               26
# 2                   73                                               21
# 3                   56                                               20
# 4                   62                                               31
#
#    Number of students who took the SHSAT
# 0                                     14
# 1                                      7
# ...
